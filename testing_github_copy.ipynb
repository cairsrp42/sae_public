# %%
print("Hello world!")

import numpy as np
import matplotlib.pyplot as plt

temp=np.zeros((3,4))
temp[1,2]=2.3
print("temp")
plt.figure()
plt.contourf(temp,cmap="jet")
# Out:
# Hello world!
# temp
